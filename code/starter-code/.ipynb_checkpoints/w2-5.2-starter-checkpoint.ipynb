# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ### The Legion of Evil is the world's #2 most evil organization in the world, but we could be number one!
# #### Through tough negotiations and uncomfortable silences, we have been granted a meeting with the #1 most evil organization, the Legion of Doom! This is our chance, recruit, to make it to the big time. Let's not fail now!

# %% [markdown]
# #### Let's start by loading in our database and printing the head

# %%
marvel = pd.read_csv('./../../assets/datasets/marvel.csv')
print marvel.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0  Living Characters       4043.0           Aug-62  1962.0
# 1  Living Characters       3360.0           Mar-41  1941.0
# 2  Living Characters       3061.0           Oct-74  1974.0
# 3  Living Characters       2961.0           Mar-63  1963.0
# 4  Living Characters       2258.0           Nov-50  1950.0

# %% [markdown]
# #### We have some extra data from our teams in the field about the comings and goings of our heroes in the list. Let's run this once and continue to the next field

# %%
def randomly(length):
    return np.random.randint(0, length, size = 1)[0]

def pull_unique(length, arr):
    this_rand = randomly(length)
    while this_rand in arr:
        this_rand = randomly(length)
    return this_rand

def make_week(number):
    return "Week: " + str(number)


columns = 35
weeks = [make_week(x + 1) for x in range(columns)]

activity = ["sleeping","jogging","general tcb(taking care of business)",
            "goat wrangling","birthday party","hopscotch tournament",
           "evil fighting","having conflicting emotions about secret identity",
           "ordering pizza","eating jellybeans","working both sides",
            "being john malkovich","Netflix and chill", "munching on granola",
            "standing silently on one leg", "using powers for good", 
            "extensive pullups","running into walls","creating portals to other dimensions",
           "being really really evil", "insulting children", "stealing puppies from orphanages",
           "masticating", "doing magic tricks", "understanding the world", "Space!!!"]

dicty = {}

for week in weeks:
    dicty[week] = [activity[randomly(len(activity))] for x in range(len(marvel))]

dicty['page_id'] = marvel['page_id']

# %% [markdown]
# #### Let's add our new data to a dataframe and print the head

# %%
weeks = pd.DataFrame(dicty)
weeks.head()
# Out:
#                             Week: 1            Week: 10  \
# 0             using powers for good  insulting children
# 1                    goat wrangling       evil fighting
# 2              hopscotch tournament   Netflix and chill
# 3  stealing puppies from orphanages  running into walls
# 4                     evil fighting            Space!!!
#
#                 Week: 11                          Week: 12  \
# 0         ordering pizza                           jogging
# 1    munching on granola  stealing puppies from orphanages
# 2   being john malkovich                    birthday party
# 3         ordering pizza                    goat wrangling
# 4  using powers for good                    ordering pizza
#
#                        Week: 13                      Week: 14  \
# 0      being really really evil          being john malkovich
# 1             extensive pullups             extensive pullups
# 2                goat wrangling           munching on granola
# 3             Netflix and chill  standing silently on one leg
# 4  standing silently on one leg                      Space!!!
#
#                        Week: 15               Week: 16  \
# 0            running into walls               Space!!!
# 1                birthday party            masticating
# 2  standing silently on one leg               Space!!!
# 3         using powers for good            masticating
# 4      being really really evil  using powers for good
#
#                                Week: 17                              Week: 18  \
# 0                    doing magic tricks                           masticating
# 1                    insulting children                        birthday party
# 2  creating portals to other dimensions                   munching on granola
# 3                  being john malkovich                    working both sides
# 4                  being john malkovich  creating portals to other dimensions
#
#     ...                                             Week: 33  \
# 0   ...    having conflicting emotions about secret identity
# 1   ...                                       goat wrangling
# 2   ...                                 being john malkovich
# 3   ...                                    extensive pullups
# 4   ...                                   running into walls
#
#                   Week: 34                                           Week: 35  \
# 0       working both sides               creating portals to other dimensions
# 1        eating jellybeans                                           Space!!!
# 2           ordering pizza                                           sleeping
# 3            evil fighting  having conflicting emotions about secret identity
# 4  understanding the world                            understanding the world
#
#                                 Week: 4  \
# 0                         evil fighting
# 1                         evil fighting
# 2                        birthday party
# 3                  hopscotch tournament
# 4  creating portals to other dimensions
#
#                                              Week: 5  \
# 0                                 working both sides
# 1                                            jogging
# 2                                           sleeping
# 3  having conflicting emotions about secret identity
# 4                           being really really evil
#
#                                              Week: 6  \
# 0  having conflicting emotions about secret identity
# 1                                  Netflix and chill
# 2                                           sleeping
# 3                                munching on granola
# 4                                  eating jellybeans
#
#                                              Week: 7  \
# 0                   stealing puppies from orphanages
# 1                               being john malkovich
# 2  having conflicting emotions about secret identity
# 3                                 running into walls
# 4               creating portals to other dimensions
#
#                     Week: 8                           Week: 9 page_id
# 0            birthday party              hopscotch tournament    1678
# 1  being really really evil                doing magic tricks    7139
# 2      being john malkovich  stealing puppies from orphanages   64786
# 3            ordering pizza                    ordering pizza    1868
# 4         eating jellybeans                 eating jellybeans    2460
#
# [5 rows x 36 columns]

# %% [markdown]
# #### Let's merge new this DataFrame with our marvel DataFrame

# %%
merged = pd.merge(marvel, weeks, how='inner', on='page_id')
merged.columns.values
# Out:
# array(['page_id', 'name', 'urlslug', 'ID', 'ALIGN', 'EYE', 'HAIR', 'SEX',
#        'GSM', 'ALIVE', 'APPEARANCES', 'FIRST APPEARANCE', 'Year',
#        'Week: 1', 'Week: 10', 'Week: 11', 'Week: 12', 'Week: 13',
#        'Week: 14', 'Week: 15', 'Week: 16', 'Week: 17', 'Week: 18',
#        'Week: 19', 'Week: 2', 'Week: 20', 'Week: 21', 'Week: 22',
#        'Week: 23', 'Week: 24', 'Week: 25', 'Week: 26', 'Week: 27',
#        'Week: 28', 'Week: 29', 'Week: 3', 'Week: 30', 'Week: 31',
#        'Week: 32', 'Week: 33', 'Week: 34', 'Week: 35', 'Week: 4',
#        'Week: 5', 'Week: 6', 'Week: 7', 'Week: 8', 'Week: 9'], dtype=object)

# %% [markdown]
# #### Let's take a look at our data to see how it came out. General Immortus tells you that "Ormond Wychwood" should be in our database, let's print out his data.

# %%
merged[merged['name'].str.contains('Ormond Wychwood')]
# Out:
#       page_id                         name                        urlslug  \
# 1016    84720  Ormond Wychwood (Earth-616)  \/Ormond_Wychwood_(Earth-616)
#
#                    ID           ALIGN        EYE        HAIR              SEX  \
# 1016  Secret Identity  Bad Characters  Blue Eyes  Blond Hair  Male Characters
#
#       GSM              ALIVE       ...        Week: 32            Week: 33  \
# 1016  NaN  Living Characters       ...        sleeping  working both sides
#
#             Week: 34           Week: 35  \
# 1016  birthday party  eating jellybeans
#
#                                                 Week: 4               Week: 5  \
# 1016  having conflicting emotions about secret identity  being john malkovich
#
#                     Week: 6             Week: 7                   Week: 8  \
# 1016  using powers for good  working both sides  being really really evil
#
#              Week: 9
# 1016  birthday party
#
# [1 rows x 48 columns]

# %% [markdown]
# #### Everything looks good! Next, let's melt our table to find the most popular activity for our heroes by week

# %%
melted = pd.melt(merged, id_vars=merged.ix[:,:'Year'].columns.values,var_name='week',value_name='activity')
melted
# Out:
#         page_id                                               name  \
# 0          1678                          Spider-Man (Peter Parker)
# 1          7139                    Captain America (Steven Rogers)
# 2         64786                Wolverine (James \"Logan\" Howlett)
# 3          1868                  Iron Man (Anthony \"Tony\" Stark)
# 4          2460                                Thor (Thor Odinson)
# 5          2458                         Benjamin Grimm (Earth-616)
# 6          2166                          Reed Richards (Earth-616)
# 7          1833                         Hulk (Robert Bruce Banner)
# 8         29481                          Scott Summers (Earth-616)
# 9          1837                         Jonathan Storm (Earth-616)
# 10        15725                            Henry McCoy (Earth-616)
# 11         1863                            Susan Storm (Earth-616)
# 12         7823                         Namor McKenzie (Earth-616)
# 13         2614                           Ororo Munroe (Earth-616)
# 14         1803                         Clinton Barton (Earth-616)
# 15         1396                        Matthew Murdock (Earth-616)
# 16        55534                        Stephen Strange (Earth-616)
# 17         1978                       Mary Jane Watson (Earth-616)
# 18         1872                     John Jonah Jameson (Earth-616)
# 19        35350                           Robert Drake (Earth-616)
# 20         1557                              Henry Pym (Earth-616)
# 21        65255                         Charles Xavier (Earth-616)
# 22         1073                 Warren Worthington III (Earth-616)
# 23         1346                         Piotr Rasputin (Earth-616)
# 24         2512                         Wanda Maximoff (Earth-616)
# 25         1671                          Nicholas Fury (Earth-616)
# 26         1976                         Janet van Dyne (Earth-616)
# 27        65219                              Jean Grey (Earth-616)
# 28         6545                       Natalia Romanova (Earth-616)
# 29         2223                            Kurt Wagner (Earth-616)
# ...         ...                                                ...
# 573130    42106                                Thiazzi (Earth-616)
# 573131   462671                                          TOR\/test
# 573132   725312                       Toxin (Luminals) (Earth-616)
# 573133   507239                          Urizen Ul'var (Earth-616)
# 573134    40061                                  Valka (Earth-616)
# 573135   505759                                  Vayor (Earth-616)
# 573136    16569                               Viridian (Earth-616)
# 573137    16296                          William Burke (Earth-616)
# 573138   120833                      William Falsworth (Earth-616)
# 573139   693077                    William Shakespeare (Earth-616)
# 573140   473710                       Yamata no Orichi (Earth-616)
# 573141   670512  Zero G. Priestly (Legion Personality) (Earth-616)
# 573142    12132                            Zora Loftus (Earth-616)
# 573143   727035                                   Agar (Earth-616)
# 573144   703546      Ana (Natasha Romanoff's neighbor) (Earth-616)
# 573145   713903                         Dante's mother (Earth-616)
# 573146   508693                               Farbauti (Earth-616)
# 573147   694577         Finch (Kate Bishop's neighbor) (Earth-616)
# 573148   655292              Jack O'Lantern (Impostor) (Earth-616)
# 573149   684262                                 K'thol (Earth-616)
# 573150   643435            Karen (Hijack's girlfriend) (Earth-616)
# 573151   694583        Marcus (Kate Bishop's neighbor) (Earth-616)
# 573152   703892               Marcy (Offer's employee) (Earth-616)
# 573153   660799                         Melanie Kapoor (Earth-616)
# 573154   674414                       Phoenix's Shadow (Earth-616)
# 573155   657508                                 Ru'ach (Earth-616)
# 573156   665474                    Thane (Thanos' son) (Earth-616)
# 573157   695217                      Tinkerer (Skrull) (Earth-616)
# 573158   708811                     TK421 (Spiderling) (Earth-616)
# 573159   673702                              Yologarch (Earth-616)
#
#                                                   urlslug                ID  \
# 0                             \/Spider-Man_(Peter_Parker)   Secret Identity
# 1                       \/Captain_America_(Steven_Rogers)   Public Identity
# 2                 \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3                   \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                                   \/Thor_(Thor_Odinson)  No Dual Identity
# 5                            \/Benjamin_Grimm_(Earth-616)   Public Identity
# 6                             \/Reed_Richards_(Earth-616)   Public Identity
# 7                            \/Hulk_(Robert_Bruce_Banner)   Public Identity
# 8                             \/Scott_Summers_(Earth-616)   Public Identity
# 9                            \/Jonathan_Storm_(Earth-616)   Public Identity
# 10                              \/Henry_McCoy_(Earth-616)   Public Identity
# 11                              \/Susan_Storm_(Earth-616)   Public Identity
# 12                           \/Namor_McKenzie_(Earth-616)  No Dual Identity
# 13                             \/Ororo_Munroe_(Earth-616)   Public Identity
# 14                           \/Clinton_Barton_(Earth-616)   Public Identity
# 15                          \/Matthew_Murdock_(Earth-616)   Public Identity
# 16                          \/Stephen_Strange_(Earth-616)   Public Identity
# 17                         \/Mary_Jane_Watson_(Earth-616)  No Dual Identity
# 18                       \/John_Jonah_Jameson_(Earth-616)  No Dual Identity
# 19                             \/Robert_Drake_(Earth-616)   Secret Identity
# 20                                \/Henry_Pym_(Earth-616)   Public Identity
# 21                           \/Charles_Xavier_(Earth-616)   Public Identity
# 22                   \/Warren_Worthington_III_(Earth-616)   Public Identity
# 23                           \/Piotr_Rasputin_(Earth-616)   Secret Identity
# 24                           \/Wanda_Maximoff_(Earth-616)   Public Identity
# 25                            \/Nicholas_Fury_(Earth-616)  No Dual Identity
# 26                           \/Janet_van_Dyne_(Earth-616)   Public Identity
# 27                                \/Jean_Grey_(Earth-616)   Public Identity
# 28                         \/Natalia_Romanova_(Earth-616)   Public Identity
# 29                              \/Kurt_Wagner_(Earth-616)   Secret Identity
# ...                                                   ...               ...
# 573130                              \/Thiazzi_(Earth-616)               NaN
# 573131                                   \/User:TOR\/test               NaN
# 573132                     \/Toxin_(Luminals)_(Earth-616)   Secret Identity
# 573133                      \/Urizen_Ul%27var_(Earth-616)   Public Identity
# 573134                                \/Valka_(Earth-616)               NaN
# 573135                                \/Vayor_(Earth-616)  No Dual Identity
# 573136                             \/Viridian_(Earth-616)               NaN
# 573137                        \/William_Burke_(Earth-616)               NaN
# 573138                    \/William_Falsworth_(Earth-616)               NaN
# 573139                  \/William_Shakespeare_(Earth-616)   Public Identity
# 573140                     \/Yamata_no_Orichi_(Earth-616)   Public Identity
# 573133     Good Characters   White Eyes          NaN    Male Characters
# 573134                 NaN          NaN          NaN                NaN
# 573135      Bad Characters          NaN   Black Hair    Male Characters
# 573136                 NaN          NaN          NaN    Male Characters
# 573137                 NaN          NaN          NaN    Male Characters
# 573138     Good Characters          NaN          NaN    Male Characters
# 573139  Neutral Characters          NaN          NaN    Male Characters
# 573140      Bad Characters          NaN      No Hair    Male Characters
# 573141  Neutral Characters          NaN          NaN    Male Characters
# 573142      Bad Characters          NaN   Blond Hair  Female Characters
# 573143      Bad Characters   Black Eyes      No Hair    Male Characters
# 573144     Good Characters   Black Eyes    Grey Hair  Female Characters
# 573145  Neutral Characters          NaN          NaN  Female Characters
# 573146      Bad Characters     Red Eyes          NaN  Female Characters
# 573147     Good Characters   Black Eyes         Bald    Male Characters
# 573148      Bad Characters   Hazel Eyes         Bald    Male Characters
# 573149     Good Characters          NaN          NaN    Male Characters
# 573150  Neutral Characters   Brown Eyes   Black Hair  Female Characters
# 573151     Good Characters   Hazel Eyes         Bald    Male Characters
# 573152  Neutral Characters          NaN   Brown Hair  Female Characters
# 573153     Good Characters    Blue Eyes   Black Hair  Female Characters
# 573154  Neutral Characters          NaN          NaN                NaN
# 573155      Bad Characters   Green Eyes      No Hair    Male Characters
# 573156     Good Characters    Blue Eyes         Bald    Male Characters
# 573157      Bad Characters   Black Eyes         Bald    Male Characters
# 573158  Neutral Characters          NaN          NaN    Male Characters
# 573159      Bad Characters          NaN          NaN                NaN
#
#                           GSM                ALIVE  APPEARANCES  \
# 0                         NaN    Living Characters       4043.0
# 1                         NaN    Living Characters       3360.0
# 2                         NaN    Living Characters       3061.0
# 3                         NaN    Living Characters       2961.0
# 4                         NaN    Living Characters       2258.0
# 5                         NaN    Living Characters       2255.0
# 6                         NaN    Living Characters       2072.0
# 7                         NaN    Living Characters       2017.0
# 8                         NaN    Living Characters       1955.0
# 9                         NaN    Living Characters       1934.0
# 10                        NaN    Living Characters       1825.0
# 11                        NaN    Living Characters       1713.0
# 12                        NaN    Living Characters       1528.0
# 13                        NaN    Living Characters       1512.0
# 14                        NaN    Living Characters       1394.0
# 15                        NaN    Living Characters       1338.0
# 16                        NaN    Living Characters       1307.0
# 17                        NaN    Living Characters       1304.0
# 18                        NaN    Living Characters       1266.0
# 19                        NaN    Living Characters       1265.0
# 20                        NaN    Living Characters       1237.0
# 21                        NaN  Deceased Characters       1233.0
# 22                        NaN    Living Characters       1230.0
# 23                        NaN    Living Characters       1162.0
# 24                        NaN    Living Characters       1161.0
# 25                        NaN    Living Characters       1137.0
# 26                        NaN    Living Characters       1120.0
# 27                        NaN  Deceased Characters       1107.0
# 28        Bisexual Characters    Living Characters       1050.0
# 29                        NaN    Living Characters       1047.0
# ...                       ...                  ...          ...
# 573130                    NaN  Deceased Characters          NaN
# 573131                    NaN                  NaN          NaN
# 573132                    NaN    Living Characters          NaN
# 573133                    NaN    Living Characters          NaN
# 573134                    NaN    Living Characters          NaN
# 573135                    NaN    Living Characters          NaN
# 573136                    NaN    Living Characters          NaN
# 573137                    NaN    Living Characters          NaN
# 573138                    NaN  Deceased Characters          NaN
# 573139                    NaN    Living Characters          NaN
# 573159              NaN     NaN  Week: 9
#
#                                                  activity
# 0                                   using powers for good
# 1                                          goat wrangling
# 2                                    hopscotch tournament
# 3                        stealing puppies from orphanages
# 4                                           evil fighting
# 5                                          ordering pizza
# 6                                 understanding the world
# 7                                    hopscotch tournament
# 8                                      doing magic tricks
# 9                            standing silently on one leg
# 10                               being really really evil
# 11                   creating portals to other dimensions
# 12                                  using powers for good
# 13                                         goat wrangling
# 14                                understanding the world
# 15                                      extensive pullups
# 16                                         goat wrangling
# 17                                      extensive pullups
# 18                                     insulting children
# 19                                     working both sides
# 20                                      eating jellybeans
# 21                                     doing magic tricks
# 22                                understanding the world
# 23                                    munching on granola
# 24                                               Space!!!
# 25                                               Space!!!
# 26                                          evil fighting
# 27                                     working both sides
# 28                                         goat wrangling
# 29                                     doing magic tricks
# ...                                                   ...
# 573130                                            jogging
# 573131                                     goat wrangling
# 573132                                      evil fighting
# 573133                               being john malkovich
# 573134               general tcb(taking care of business)
# 573135                                     goat wrangling
# 573136                                 insulting children
# 573137               creating portals to other dimensions
# 573138                                     birthday party
# 573139                                 working both sides
# 573140                                  Netflix and chill
# 573141                                  eating jellybeans
# 573142               creating portals to other dimensions
# 573143                                           sleeping
# 573144                                 insulting children
# 573145                                munching on granola
# 573146                                      evil fighting
# 573147                                     ordering pizza
# 573148               creating portals to other dimensions
# 573149                                            jogging
# 573150                               being john malkovich
# 573151                            understanding the world
# 573152  having conflicting emotions about secret identity
# 573153  having conflicting emotions about secret identity
# 573154                                     birthday party
# 573155                                     goat wrangling
# 573156                                munching on granola
# 573157                                 doing magic tricks
# 573158                            understanding the world
# 573159                                  eating jellybeans
#
# [573160 rows x 15 columns]

# %% [markdown]
# #### We are concerned about the activities of our valiant evil heroes vs. the unambitious good heroes. Let's print out a pivot table showing the differences. An example table can be found below.

# %%
melted_table = pd.pivot_table(melted[['ALIGN','activity']], index=['ALIGN'],columns=['activity'], aggfunc=len, fill_value=0)
melted_table
# Out:
# activity            Netflix and chill  Space!!!  being john malkovich  \
# ALIGN
# Bad Characters                   9171      8814                  9003
# Good Characters                  6128      6260                  6179
# Neutral Characters               2896      3028                  2925
#
# activity            being really really evil  birthday party  \
# ALIGN
# Bad Characters                          8997            9032
# Good Characters                         6205            6218
# Neutral Characters                      3032            2960
#
# activity            creating portals to other dimensions  doing magic tricks  \
# ALIGN
# Bad Characters                                      9030                8921
# Good Characters                                     6319                6229
# Neutral Characters                                  2949                2997
#
# activity            eating jellybeans  evil fighting  extensive pullups  \
# ALIGN
# Bad Characters                   8982           9138               8956
# Good Characters                  6343           6297               6144
# Neutral Characters               2869           3081               2891
#
# activity                   ...          masticating  munching on granola  \
# ALIGN                      ...
# Bad Characters             ...                 9025                 9061
# Good Characters            ...                 6178                 6278
# Neutral Characters         ...                 2964                 3061
#
# activity            ordering pizza  running into walls  sleeping  \
# ALIGN
# Bad Characters                9196                8974      9037
# Good Characters               6238                6197      6338
# Neutral Characters            3038                2910      2974
#
# activity            standing silently on one leg  \
# ALIGN
# Bad Characters                              8980
# Good Characters                             6139
# Neutral Characters                          2951
#
# activity            stealing puppies from orphanages  understanding the world  \
# ALIGN
# Bad Characters                                  8992                     8982
# Good Characters                                 6114                     6194
# Neutral Characters                              2982                     3040
#
# activity            using powers for good  working both sides
# ALIGN
# Bad Characters                       9011                9066
# Good Characters                      6317                6281
# Neutral Characters                   2980                2966
#
# [3 rows x 26 columns]

# %% [markdown]
# #### Are our freedom fighters better at being evil on average? Let's make a boxplot of the number of times each character had an evil action against how they are aligned (evil, neutral, good). You can see a sample of the plot we are looking for below this cell.

# %%
evil_activities = ["working both sides","creating portals to other dimensions",
           "being really really evil", "insulting children", "stealing puppies from orphanages"]


melted.index = melted['activity']

new_table = melted.ix[evil_activities]

newer_table = pd.pivot_table(new_table, values=['activity'], index=['name'], columns=['ALIGN'], aggfunc=len)
newer_table
newer_table.plot(kind='box', figsize=(10,10))
plt.show()

# %% [markdown]
# ![Box](./../../assets/plot_1.png "Box")

# %% [markdown]
# #### Now let's make a bar graph with pandas with the averages of the sum totals (evil / all activites) for our alignments. Which alignment on average was the most evil? Don't forget to give your chart a title and label your axis' recruits!

# %%
tot = pd.pivot_table(melted, values=['activity'], columns=['ALIGN'], aggfunc=len)
total = float(tot['Good Characters']) + float(tot['Bad Characters']) + float(tot['Neutral Characters'])
print total
avg = pd.pivot_table(new_table, values=['activity'], columns=['ALIGN'], aggfunc=len)

avg['Good Characters'] = float(avg['Good Characters']) / total
avg['Bad Characters'] = float(avg['Bad Characters']) / total
avg['Neutral Characters'] = float(avg['Neutral Characters']) / total
print tot
print total
print avg
ax = avg.plot(kind='bar', title='Evil Deeds by Alignment', figsize=(10,10))
ax.set_xlabel('Alignment')
ax.set_ylabel('Evil Deeds')
plt.show()
# Out:
# 474740.0
# ALIGN     Bad Characters  Good Characters  Neutral Characters
# activity          235200           162260               77280
# 474740.0
# ALIGN     Bad Characters  Good Characters  Neutral Characters
# activity        0.095606         0.065583            0.031272

# %% [markdown]
# ![Bar](./../../assets/plot_2.png "Bar")

# %% [markdown]
# #### Lex Luther ([Enterprising Leader of the Legion Of Doom](https://en.wikipedia.org/wiki/Legion_of_Doom_(DC_Comics)) has contracted you on one last personal project: To engineer a unique, cutting-edge slideshow for the lobby of the Legion of Doom! Here are the steps needed to complete the task.
#
# * Replace each of your heroes activities with numbers denoting their alignment
#     * 1 = good
#     * -1 = evil
#     * 0 = neutral (all activities not in good_activity or evil_activity lists)
# * Pick a random hero from your dataset
# * Plot his evilness/goodness over time with a line graph
# * Make sure to print his name at the top of the graph and label your x and y axis!

# %%
good_activity = ["birthday party","evil fighting",
                 "having conflicting emotions about secret identity",
           "using powers for good", "understanding the world", "Space!!!"]


spdrmn = merged.ix[merged['name'].str.contains('Spiderman'),'Week: 1':]


alm_neut = [i for i in spdrmn.ix[11414] if i not in good_activity]
neut = [i for i in spdrmn.ix[11414]if i not in evil_activities]

 
spdrmn.replace(good_activity, 1, inplace=True)
spdrmn.replace(evil_activities, -1, inplace=True)
spdrmn.replace(neut, 0, inplace=True)
spdrmn = np.transpose(spdrmn)
ax = spdrmn.plot(lw=2,title='Spiderman', figsize=(10, 10))
ax.set_xlabel('Week of Evil')
ax.set_ylabel('Deed Alignment')

plt.show()

# %% [markdown]
# ![Bar](./../../assets/plot_3.png "Bar")
